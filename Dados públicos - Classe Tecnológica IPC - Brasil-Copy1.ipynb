# %% [markdown]
# O objetivo desse script é criar tabelas para analisar a quantidade de pedidos de patentes no Brasil de acordo com a localidade e a classe tecnológica da patente. Os dados utilizados são as bases de dados do INPI e o registro de municípios feito pelo IBGE. Links para encontrar esses dados estão abaixo:
#
# Dados do INPI, ou BADEPI (Base de Dados sobre Propriedade Intelectual):
# https://www.gov.br/inpi/pt-br/central-de-conteudo/estatisticas-e-estudos-economicos/estatisticas-1/base-de-dados-sobre-propriedade-intelectual-para-fins-estatisticos-2013-badepi
#
# Dados do IBGE:
# https://www.ibge.gov.br/geociencias/organizacao-do-territorio/estrutura-territorial/23701-divisao-territorial-brasileira.html?=&t=downloads&utm_source=landing&utm_medium=explica&utm_campaign=codmun

# %%
# Bibliotecas usadas:
import pandas as pd

# Configuração para ver todas as colunas
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Carregando e tratando os dados brasileiros
#
# Os dados relevantes estão em quatro arquivos distintos: depositantes, depósitos, classificações e municipios. Esses arquivos serão carregados com as variáveis relevantes para a análise.
#
# Ao final, as tabelas individuais serão reunidas em uma variável chamada 'dados'.
# Comum às tabelas do INPI:

# %% [markdown]
# ## Depositantes

# %% [markdown]
# ### Carregando os dados
#
# A tabela de depositantes fornece as informações dos depositantes para cada pedido de patente. Ela é relevante pois o primeiro depositante é usado para identificar a localização de cada patente. Portanto, iremos carregar os dados relativos à localização e selecioná-los para o Brasil e o primeiro depositante.
#
# depositantes ('PTN_DEPOSITANTES.csv'):
# - NO_PEDIDO, variável chave e identificador da patente
# - NO_ORDEM, número atribuído ao depositante de acordo com a ordem no pedido
# - PAIS, país de origem/sede do depositante
# - UF, estado de origem/sede do depositante
# - MUNICIPIO, município de origem/sede do depositante
# - CD_IBGE_CIDADE, código do município associado

# %%
# carregando os dados de depositantes
depositantes = pd.read_csv(
    'dados/PTN_DEPOSITANTES.csv',
    sep = ';',
    encoding = 'latin1',
    low_memory = False,
    usecols = ['NO_PEDIDO', 'NO_ORDEM', 'PAIS', 'UF', 'MUNICIPIO', 'CD_IBGE_CIDADE']
)

# selecionando os dados para o Brasil
selecao = depositantes['PAIS'] == 'BR'
depositantes = depositantes[selecao]
depositantes.drop('PAIS', axis='columns', inplace=True)

# selecionando o primeiro depositante
selecao = depositantes['NO_ORDEM'] == 1
depositantes = depositantes[selecao]
depositantes.drop('NO_ORDEM', axis='columns', inplace=True)

depositantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150515 entries, 0 to 514623
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   NO_PEDIDO       150515 non-null  object
#  1   UF              149731 non-null  object
#  2   MUNICIPIO       134262 non-null  object
#  3   CD_IBGE_CIDADE  127955 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 5.7+ MB

# %% [markdown]
# ### Tratando os dados
#
# Os dados de depositantes não são os melhores possíveis. Há diversos dados faltantes e, em alguns casos, dados incoerentes, como o caso da patente depositada na cidade de Londrina (AC) (ver patente PI0605762, encontrada ao executar da linha de código: "dados[dados['NO_PEDIDO'] == 'PI0605762']"). Devido a esses problemas iremos usar somente os dados de patentes que possuem o código do IBGE, já que estes garantem uma localização única e coerente para cada patente. Perdemos um número razoável de dados devido a isso, mas há pouco a se fazer em relação a isso. Códigos da cidade serão usados posteriormente para unir os dados do INPI com os dados de local do IBGE.
#
# Outro tratamento que podemos dar aos dados de depositantes é remover os pedidos duplicados, já que é esperado contar somente uma vez cada patente de acordo com seu local.
#
# O NO_PEDIDO será feito de índice da tabela. A coluna MUNICIPIO será excluída, enquanto a coluna UF e CD_IBGE_CIDADE serão mantidas pois servirão de referência posterior para agregar os dados.

# %%
# removendo patentes sem o código de cidade
depositantes.dropna(subset=['CD_IBGE_CIDADE'], inplace=True)

# removendo patentes repetidas
depositantes.drop_duplicates(subset=['NO_PEDIDO'], inplace=True)

# removendo coluna dos municipios
depositantes.drop(columns=['MUNICIPIO'], inplace=True)

depositantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127874 entries, 0 to 514623
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   NO_PEDIDO       127874 non-null  object
#  1   UF              127874 non-null  object
#  2   CD_IBGE_CIDADE  127874 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 3.9+ MB

# %% [markdown]
# ## Depósitos

# %% [markdown]
# ### Carregando os dados
#
# A tabela de depósitos é relevante pois fornece as datas de depósito de cada pedido de patente.
#
# depositos ('PTN_DEPOSITOS.csv'):
# - NO_PEDIDO, variável chave e identificador da patente
# - DT_DEPOSITO, data de depósito da patente e inicial para determinar seu prazo de vigência

# %%
# carregando os dados de depositos
depositos = pd.read_csv(
    'dados/PTN_DEPOSITOS.csv',
    sep = ';',
    encoding = 'latin1',
    usecols = ['NO_PEDIDO', 'DT_DEPOSITO']
)

# convertendo datas para o formato datetime
depositos['DT_DEPOSITO'] = pd.to_datetime(depositos['DT_DEPOSITO'], errors='coerce')

depositos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611227 entries, 0 to 611226
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   NO_PEDIDO    611227 non-null  object
#  1   DT_DEPOSITO  611200 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 9.3+ MB

# %% [markdown]
# ### Tratando os dados
#
# Os tratamentos que penso ser possível para esses dados é eliminar os número de patentes repetidos e as datas de depósitos faltantes.

# %%
# removendo depositos de patentes duplicados
depositos.drop_duplicates(subset=['NO_PEDIDO'], inplace=True)

# removendo datas de depósitos faltantes
depositos.dropna(subset=['DT_DEPOSITO'], inplace=True)

depositos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611200 entries, 5 to 611226
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   NO_PEDIDO    611200 non-null  object
#  1   DT_DEPOSITO  611200 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 14.0+ MB

# %% [markdown]
# ## Classificações tecnológicas

# %% [markdown]
# ### Carregando os dados
#
# A tabela de classificações tecnológicas nos fornece os dados da classificação tecnológicas das patentes. Usaremos só as classificações IPC, desconsiderando as classificações fornecidas pela INPI. Também renomearemos as variáveis relativas ao código IPC para torná-las mais claras.
#
# classificacoes ('PTN_CLASSIFICACOES.csv'):
# - NO_PEDIDO, variável chave e identificador da patente
# - NO_ORDEM_PEDIDO, ordem dos códigos IPC no momento de atribuição, renomeada para 'IPC_ORDEM'
# - CD_CLASSIF, classificação IPC da patente, renomeada para 'IPC_CD'

# %%
# carregando os dados de classificação das patentes
classificacoes = pd.read_csv(
    'dados/PTN_CLASSIFICACOES.csv',
    sep = ';',
    usecols = ['NO_PEDIDO', 'NO_ORDEM_PEDIDO', 'CD_CLASSIF']
)

# criando novos nomes
novos_nomes = {
    'NO_ORDEM_PEDIDO': 'IPC_ORDEM',
    'CD_CLASSIF': 'IPC_CD'
}

# renomeando
classificacoes.rename(columns=novos_nomes, inplace=True)

classificacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153723 entries, 0 to 1153722
# Data columns (total 3 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   NO_PEDIDO  1153723 non-null  object
#  1   IPC_ORDEM  1153723 non-null  int64
#  2   IPC_CD     1153723 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 26.4+ MB

# %% [markdown]
# ### Tratando os dados
#
# Não foi identificada nenhum tratamento de dados possível para as classificações tecnológicas.

# %% [markdown]
# ## Divisões do território segundo o IBGE

# %% [markdown]
# ### Carregando os dados
#
# Por fim temos a tabela do IBGE. Esses dados serão incorporados para facilitar a agregação por níveis diferentes de localidade, sendo a mais ampla por unidades da federação, passando pelas regiões intermediárias e imediatas, seguindo o novo recorte divulgado pelo IBGE em 2017, ou as antigas mesorregiões e microrregiões, até chegar ao município. Além do código do município, usado para unir as tabelas, serão carregados os nomes dessas subdivisões geográficas. As colunas serão renomeadas para facilitar referência posterior. De antemão é possível dizer que não há razão para um tratamento desses dados.
#
# territorios_ibge ('RELATORIO_DTB_BRASIL_MUNICIPIO.xls'):
# - Nome_UF, não será renomeado, preferível usar a variável UF dos dados do INPI
# - Nome Região Geográfica Intermediária, renomeado RG_INTERMED
# - Nome Região Geográfica Imediata, renomeada RG_IMEDI
# - Nome_Mesorregião, renomeada MESORREGIAO
# - Nome_Microrregião, renomeada MICRORREGIAO
# - Código Município Completo, usada para unir as tabelas e depois removida
# - Nome_Município, renomeada MUNICIPIO

# %%
# carregando dados dos municípios
territorios = pd.read_excel(
    'dados/RELATORIO_DTB_BRASIL_MUNICIPIO.xls',
    usecols = [
        'Nome_UF',
        'Nome Região Geográfica Intermediária',
        'Nome Região Geográfica Imediata',
        'Nome_Mesorregião',
        'Nome_Microrregião',
        'Código Município Completo',
        'Nome_Município'
    ]
)

# criando novos nomes
novos_nomes = {
    'Nome Região Geográfica Intermediária': 'RG_INTERMED',
    'Nome Região Geográfica Imediata': 'RG_IMEDI',
    'Nome_Mesorregião': 'MESORREGIAO',
    'Nome_Microrregião': 'MICRORREGIAO',
    'Nome_Município': 'MUNICIPIO'
}

# renomeando
territorios.rename(columns=novos_nomes, inplace=True)

territorios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Nome_UF                    5570 non-null   object
#  1   RG_INTERMED                5570 non-null   object
#  2   RG_IMEDI                   5570 non-null   object
#  3   MESORREGIAO                5570 non-null   object
#  4   MICRORREGIAO               5570 non-null   object
#  5   Código Município Completo  5570 non-null   int64
#  6   MUNICIPIO                  5570 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 304.7+ KB

# %% [markdown]
# ## Unindo as tabelas

# %% [markdown]
# Agora que os dados foram selecionados e tratados, cabe uni-los em uma única tabela chamada 'dados' para facilitar a manipulação e execução das análises. É importante ficar atento no como essa união de tabelas será feita para não perder informações! Em cada etapa será adicionado um argumento de validação na função 'merge' do pandas. Cabe pensar se as variáveis de referência, número de pedido e código de município são únicas ou múltiplas em cada tabela.
#
# 'depositantes':
# - 'NO_PEDIDO' únicos
# - 'CD_IBGE_CIDADE' múltiplos
#
# 'depósitos':
# - 'NO_PEDIDO' únicos
#
# 'classificacoes':
# - 'NO_PEDIDO' múltiplos
#
# 'territorios':
# - 'Código Município Completo' únicos
#
# Dado que 'depositantes' já esta filtrado para o Brasil, iniciaremos unindo ela a 'territorios', garantindo que seja uma relação de muitos para um.
#
# Depois disso, uniremos 'depositos' aos dados, em uma relação de um para um.
#
# Os dados contidos em 'classificacoes' será o último, em uma relação de um para muitos.
#
# Após as uniões, 'dados' conterá todas as informações relevantes.

# %%
# unindo depositantes e territorios em dados
dados = pd.merge(
    depositantes, territorios,
    how='left',
    left_on='CD_IBGE_CIDADE',
    right_on='Código Município Completo',
    validate='many_to_one'
)

# removendo colunas relativas aos códigos de município
dados.drop(['Código Município Completo'], axis='columns', inplace=True)

# unindo dados e depositos
dados = pd.merge(
    dados, depositos,
    how='left',
    on='NO_PEDIDO',
    validate='one_to_one'
)

# unindo dados e classificacoes
dados = pd.merge(
    dados, classificacoes,
    how='left',
    on='NO_PEDIDO',
    validate='one_to_many'
)


dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 223156 entries, 0 to 223155
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   NO_PEDIDO       223156 non-null  object
#  1   UF              223156 non-null  object
#  2   CD_IBGE_CIDADE  223156 non-null  float64
#  3   Nome_UF         223156 non-null  object
#  4   RG_INTERMED     223156 non-null  object
#  5   RG_IMEDI        223156 non-null  object
#  6   MESORREGIAO     223156 non-null  object
#  7   MICRORREGIAO    223156 non-null  object
#  8   MUNICIPIO       223156 non-null  object
#  9   DT_DEPOSITO     223156 non-null  datetime64[ns]
#  10  IPC_ORDEM       222138 non-null  float64
#  11  IPC_CD          222138 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 22.1+ MB

# %% [markdown]
# ## Tratamento final, otimização e reorganização dos dados
#
# Observando os dados em uma única tabela, é possível observar que nem todas as patentes que estavam presentes em depósitos ou depositantes possuíam uma classificação tecnológica, algo que devemos considerar agora. Logo, removeremos essas patentes com os dados faltantes.
#
# Além deste último tratamento dos dados, podemos otimizar alguns usos de memória. Primeiro, podemos excluir as tabelas usadas para carregar os dados antes da união. A ordem do IPC também será convertida de float para int. Outras medidas poderiam ser tomadas, mas já que os dados não estão ocupando muita memória, não complicarei demais esse processo de otimização.
#
# Por fim, é possível reorganizar as colunas de dados para que as informações mais relevantes estejam mais visíveis. Por exemplo, é mais interessante saber a data de depósito e o código IPC dos pedidos de patentes do que a microrregião a qual ela pertence.

# %%
# último tratamento dos dados, removendo dados faltantes
dados.dropna(subset=['IPC_CD', 'IPC_ORDEM'], inplace=True)

# otimização de memória
del depositantes
del territorios
del depositos
del classificacoes
dados['IPC_ORDEM'] = dados['IPC_ORDEM'].astype('int')

# reorganização dos dados
dados = dados.iloc[:, [0, 9, 11, 10, 1, 8, 4, 5, 6, 7, 3, 2]]

dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222138 entries, 0 to 223155
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   NO_PEDIDO       222138 non-null  object
#  1   DT_DEPOSITO     222138 non-null  datetime64[ns]
#  2   IPC_CD          222138 non-null  object
#  3   IPC_ORDEM       222138 non-null  int32
#  4   UF              222138 non-null  object
#  5   MUNICIPIO       222138 non-null  object
#  6   RG_INTERMED     222138 non-null  object
#  7   RG_IMEDI        222138 non-null  object
#  8   MESORREGIAO     222138 non-null  object
#  9   MICRORREGIAO    222138 non-null  object
#  10  Nome_UF         222138 non-null  object
#  11  CD_IBGE_CIDADE  222138 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int32(1), object(9)
# memory usage: 21.2+ MB

# %% [markdown]
# # Gerando a tabela RTA

# %%
# função que gera a tabela

def gerar_tabela_RTA(df, uf='', agregar_por='UF', ipc=4, inicio=1996, fim=2020):
    
    # para evitar dupla contagem, utiliza-se somente o primeiro código ipc de cada patente
    df = df[df['IPC_ORDEM'] == 1]
    
    # selecionando os dados
    if uf != '':
        df = df[df['UF'] == uf]
        
    df = df[df['DT_DEPOSITO'].dt.year >= inicio]
    df = df[df['DT_DEPOSITO'].dt.year <= fim]
    
    # criando série de referência para distribuição proporcional geral
    grupo1 = df.groupby([df['IPC_CD'].str[0:ipc]]).size()
    serie_referencia = grupo1/df.shape[0]
    
    # calculando a tabela com valores absolutos de pedidos de patentes
    grupo2 = df.groupby([agregar_por, df['IPC_CD'].str[0:ipc]], as_index=False).size()
    tabela_absolutos = grupo2.pivot(index='IPC_CD', columns=agregar_por, values='size')
    tabela_absolutos = tabela_absolutos.transform(lambda x: x.fillna(0))
    
    # tabela com valores absolutos contém a lista das regioes de acordo com a agregação...
    lista_regioes = list(tabela_absolutos.columns)
    
    # ... e serve de modelo para as tabelas com valores proporcionais e RTA!
    tabela_proporcional = tabela_absolutos
    tabela_RTA = tabela_absolutos
    
    # gerando tabela proporcional
    for regiao in lista_regioes:
        tabela_proporcional[regiao] = tabela_absolutos[regiao]/tabela_absolutos[regiao].sum()
    
    # gerando tabela RTA
    for regiao in lista_regioes:
        tabela_RTA[regiao] = (tabela_proporcional[regiao] >= serie_referencia).transform(lambda x: int(x))
    
    return tabela_RTA

# %%
# possíveis combinações:

# seleção por estado
ufs = ['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO',
       'MA', 'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR',
       'RJ', 'RN', 'RO', 'RR', 'RS', 'SC', 'SE', 'SP', 'TO']

# seleção por anos
anos = [i for i in range(1996, 2021)]  # há dados de 1996 até 2020

# agregação por nível regional
regioes = [
    'UF',            # 'Nome_UF' também pode ser usada caso queira ver o nome completo das UFs
    'RG_INTERMED',   # Região Geográfica Intermediária
    'RG_IMEDI',      # Região Geográfica Imediata'
    'MESORREGIAO',
    'MICRORREGIAO',
    'MUNICIPIO'
]

# agregação por número de dígitos do código IPC
ipc_digitos = [1, 2, 3, 4]  # recortes do IPC acima disso são muito específicos

# %%
tabela_RTA = gerar_tabela_RTA(
    dados,
    uf = '',
    agregar_por = 'RG_IMEDI',
    ipc = 3,
    inicio = 1996,
    fim = 2020
)

tabela_RTA
# Out:
# RG_IMEDI  Abaetetuba  Abaeté  Adamantina - Lucélia  \
# IPC_CD
# A01                1       1                     1
# A21                0       0                     0
# A22                0       0                     0
# A23                0       0                     0
# A24                0       0                     0
# ...              ...     ...                   ...
# H02                0       0                     0
# H03                0       0                     0
# H04                0       1                     0
# H05                0       0                     0
# H99                0       0                     0
#
# RG_IMEDI  Afonso Cláudio - Venda Nova do Imigrante - Santa Maria de Jetibá  \
# IPC_CD
# A01                                                       1
# A21                                                       1
# A22                                                       0
# A23                                                       0
# A24                                                       0
# ...                                                     ...
# H02                                                       1
# H03                                                       0
# H04                                                       0
# H05                                                       0
# H99                                                       0
#
# RG_IMEDI  Aimorés - Resplendor  Alagoinhas  Alegre  Alfenas  Almenara  \
# IPC_CD
# A01                          0           0       1        1         0
# A21                          0           0       0        0         0
# A22                          0           0       0        0         0
# A23                          0           1       1        1         0
# A24                          0           0       0        0         0
# ...                        ...         ...     ...      ...       ...
# H02                          0           1       0        1         0
# H03                          0           0       0        0         0
# H04                          0           0       0        1         0
# H05                          0           0       0        1         0
# H99                          0           0       0        0         0
#
# RG_IMEDI  Alta Floresta  Além Paraíba  Amambai  Amparo  Andradina  \
# IPC_CD
# A01                   1             0        0       1          1
# A21                   0             0        0       0          0
# A22                   0             0        0       0          0
# A23                   0             0        0       0          1
# A24                   0             0        0       0          0
# ...                 ...           ...      ...     ...        ...
# H02                   0             0        0       0          0
# H03                   0             0        0       0          0
# H04                   0             0        0       0          1
# H05                   0             0        0       1          0
# H99                   0             0        0       0          0
#
# RG_IMEDI  Angra dos Reis  Anápolis  Apucarana  Aquidauana - Anastácio  \
# IPC_CD
# A01                    0         1          1                       0
# A21                    0         0          0                       0
# A22                    0         1          0                       0
# A23                    0         0          1                       0
# A24                    0         1          0                       0
# ...                  ...       ...        ...                     ...
# H02                    0         0          1                       0
# H03                    0         0          0                       0
# H04                    1         0          0                       0
# H05                    0         1          1                       0
# H99                    0         0          0                       0
#
# RG_IMEDI  Aracaju  Aracati  Araguaína  Arapiraca  Araranguá  Araraquara  \
# IPC_CD
# A01             1        1          1          0          1           1
# A21             1        0          0          1          0           0
# A22             0        0          0          0          0           0
# A23             1        0          1          0          1           1
# A24             0        0          0          0          1           0
# ...           ...      ...        ...        ...        ...         ...
# H02             0        0          1          1          0           0
# H03             0        0          0          0          0           1
# H04             0        0          0          0          0           0
# H05             1        0          0          0          1           0
# H99             0        0          0          0          0           0
#
# RG_IMEDI  Araras  Araripina  Araxá  Araçatuba  Araçuaí  Arcoverde  Ariquemes  \
# IPC_CD
# A01            1          0      1          0        0          1          0
# A21            0          0      1          0        0          0          0
# A22            0          0      0          0        0          0          0
# A23            0          0      1          1        0          1          1
# A24            0          0      0          0        0          0          0
# ...          ...        ...    ...        ...      ...        ...        ...
# H02            0          0      1          0        0          0          1
# H03            0          0      0          0        0          0          0
# H04            0          0      1          1        0          0          0
# H05            0          0      1          0        0          0          0
# H99            0          0      0          0        0          0          0
#
# RG_IMEDI  Assis  Avaré  Açailândia  Açu  Bacabal  Bagé  Balsas  Barbacena  \
# IPC_CD
# A01           1      1           1    0        0     1       0          0
# A21           0      0           0    0        0     0       0          0
# A22           0      0           0    0        0     0       0          0
# A23           0      1           1    1        1     0       0          1
# A24           0      0           0    0        0     0       0          0
# ...         ...    ...         ...  ...      ...   ...     ...        ...
# H02           0      0           0    0        0     0       0          1
# H03           1      0           0    0        0     0       0          0
# H04           0      0           0    0        0     1       0          0
# H05           0      0           0    0        0     0       0          0
# H99           0      0           0    0        0     0       0          0
#
# RG_IMEDI  Barra do Corda  Barra do Garças  Barreiras  Barreiros - Sirinhaém  \
# IPC_CD
# A01                    0                0          1                      0
# A21                    0                0          0                      0
# A22                    0                0          0                      0
# A23                    0                0          0                      1
# A24                    0                1          0                      0
# ...                  ...              ...        ...                    ...
# H02                    0                0          0                      0
# H03                    0                0          0                      0
# H04                    0                0          1                      0
# H05                    0                0          0                      0
# H99                    0                0          0                      0
#
# RG_IMEDI  Barretos  Bauru  Belo Horizonte  Belo Jardim ¿ Pesqueira  Belém  \
# IPC_CD
# A01              1      1               0                        0      0
# A21              1      1               0                        0      1
# A22              1      0               0                        0      0
# A23              1      0               0                        0      1
# A24              1      1               0                        0      0
# ...            ...    ...             ...                      ...    ...
# H02              1      0               1                        1      0
# H03              0      1               0                        0      1
# H04              0      0               1                        1      0
# H05              0      1               1                        1      0
# H99              0      0               1                        0      0
#
# RG_IMEDI  Bento Gonçalves  Birigui - Penápolis  Blumenau  Boa Vista  \
# IPC_CD
# A01                     0                    0         0          0
# A21                     0                    0         1          0
# A22                     0                    0         0          0
# A23                     0                    0         0          1
# A24                     0                    0         1          1
# ...                   ...                  ...       ...        ...
# H02                     0                    0         1          1
# H03                     0                    0         0          0
# H04                     0                    0         0          0
# H05                     0                    0         0          0
# H99                     0                    0         0          0
#
# RG_IMEDI  Bom Jesus da Lapa  Botucatu  Bragança Paulista  Brasiléia  Breves  \
# IPC_CD
# A01                       0         1                  0          0       0
# A21                       0         1                  1          0       0
# A22                       0         0                  1          0       0
# A23                       0         1                  0          0       0
# A24                       0         0                  1          0       0
# ...                     ...       ...                ...        ...     ...
# H02                       0         0                  0          0       0
# H03                       0         1                  1          0       0
# H04                       0         0                  0          0       0
# H05                       0         0                  1          0       0
# H99                       0         0                  0          0       0
#
# RG_IMEDI  Brumado  Brusque  Cabo Frio  Cachoeira do Sul  \
# IPC_CD
# A01             0        0          0                 1
# A21             0        1          1                 1
# A22             0        1          0                 0
# A23             0        0          1                 1
# A24             0        0          0                 0
# ...           ...      ...        ...               ...
# H02             0        1          1                 0
# H03             0        0          0                 0
# H04             0        0          1                 0
# H05             0        1          1                 0
# H99             0        0          0                 0
#
# RG_IMEDI  Cachoeiro de Itapemirim  Cacoal  Caicó  Cajazeiras  \
# IPC_CD
# A01                             1       0      1           0
# A21                             0       0      0           0
# A22                             0       0      0           0
# A23                             0       1      0           0
# A24                             0       0      0           0
# ...                           ...     ...    ...         ...
# H02                             0       0      0           0
# H03                             0       0      0           0
# H04                             0       0      0           0
# H05                             0       0      0           0
# H99                             0       0      0           0
#
# RG_IMEDI  Caldas Novas-Morrinhos  Camacan  Camaquã  Campina Grande  Campinas  \
# IPC_CD
# A01                            1        1        1               0         0
# A21                            0        0        1               1         0
# A22                            0        0        0               1         0
# A23                            0        0        1               1         0
# A24                            0        0        1               0         0
# ...                          ...      ...      ...             ...       ...
# H02                            0        0        0               0         1
# H03                            0        0        0               0         1
# H04                            0        0        0               1         1
# H05                            0        0        0               0         0
# H99                            0        0        0               0         0
#
# RG_IMEDI  Campo Belo  Campo Grande  Campo Maior  Campo Mourão  \
# IPC_CD
# A01                1             1            0             1
# A21                0             1            0             0
# A22                0             0            0             0
# A23                0             1            0             0
# A24                0             1            0             0
# ...              ...           ...          ...           ...
# H02                0             0            0             1
# H03                0             1            0             0
# H04                0             0            0             0
# H05                0             0            0             1
# H99                0             0            0             0
#
# RG_IMEDI  Campos dos Goytacazes  Canguaretama  Canindé  Capelinha  Caracaraí  \
# IPC_CD
# A01                           1             0        0          1          0
# A21                           1             0        0          0          0
# A22                           0             1        0          0          0
# A23                           1             0        1          0          0
# A24                           0             0        0          0          0
# ...                         ...           ...      ...        ...        ...
# H02                           1             0        0          0          0
# H03                           0             0        0          0          0
# H04                           0             0        0          0          0
# H05                           0             0        0          0          0
# H99                           0             0        0          0          0
#
# RG_IMEDI  Caraguatatuba - Ubatuba - São Sebastião  Carangola  Caratinga  \
# IPC_CD
# A01                                             0          1          1
# A21                                             0          0          0
# A22                                             0          0          0
# A23                                             0          1          0
# A24                                             0          0          1
# ...                                           ...        ...        ...
# H02                                             1          0          1
# H03                                             0          0          0
# H04                                             1          0          0
# H05                                             1          0          0
# H99                                             0          0          0
#
# RG_IMEDI  Carazinho  Carpina  Caruaru  Cascavel  Castanhal  Cataguases  \
# IPC_CD
# A01               1        0        1         1          0           0
# A21               0        0        0         1          0           1
# A22               0        0        0         1          0           0
# A23               0        0        0         1          1           0
# A24               0        0        0         1          0           0
# ...             ...      ...      ...       ...        ...         ...
# H02               0        1        0         0          0           1
# H03               0        0        0         0          0           0
# H04               0        0        1         0          0           1
# H05               0        0        1         0          0           1
# H99               0        0        0         0          0           0
#
# RG_IMEDI  Catalão  Catanduva  Caxambu - Baependi  Caxias do Sul  Caçador  \
# IPC_CD
# A01             1          1                   0              0        1
# A21             0          1                   0              1        0
# A22             0          0                   0              0        0
# A23             0          1                   0              0        1
# A24             0          0                   0              0        0
# ...           ...        ...                 ...            ...      ...
# H02             0          0                   0              0        0
# H03             0          0                   0              0        0
# H04             1          0                   0              0        0
# H05             0          0                   0              0        0
# H99             0          0                   0              0        0
#
# RG_IMEDI  Ceres - Rialma - Goianésia  Cerro Largo  Chapadinha  Chapecó  \
# IPC_CD
# A01                                0            1           0        1
# A21                                0            0           0        1
# A22                                0            0           0        1
# A23                                0            0           0        1
# A24                                0            0           0        0
# ...                              ...          ...         ...      ...
# H02                                0            0           0        0
# H03                                0            0           0        0
# H04                                0            0           0        0
# H05                                0            0           0        1
# H99                                0            0           0        0
#
# RG_IMEDI  Charqueadas - Triunfo - São Jerônimo  Cianorte  Colatina  \
# IPC_CD
# A01                                          0         1         0
# A21                                          0         0         0
# A22                                          0         0         1
# A23                                          0         1         0
# A24                                          0         0         0
# ...                                        ...       ...       ...
# H02                                          0         0         1
# H03                                          0         0         0
# H04                                          0         0         0
# H05                                          0         0         0
# H99                                          0         0         0
#
# RG_IMEDI  Colinas do Tocantins  Conceição do Coité  Concórdia  \
# IPC_CD
# A01                          0                   0          1
# A21                          0                   0          0
# A22                          0                   0          1
# A23                          0                   0          1
# A24                          0                   0          0
# ...                        ...                 ...        ...
# H02                          0                   0          1
# H03                          0                   0          0
# H04                          0                   0          0
# H05                          0                   0          1
# H99                          0                   0          0
#
# RG_IMEDI  Confresa - Vila Rica  Conselheiro Lafaiete  \
# IPC_CD
# A01                          0                     0
# A21                          0                     0
# A22                          0                     0
# A23                          0                     0
# A24                          0                     0
# ...                        ...                   ...
# H02                          0                     0
# H03                          0                     0
# H04                          0                     1
# H05                          0                     0
# H99                          0                     0
#
# RG_IMEDI  Cornélio Procópio ¿ Bandeirantes  Corumbá  Coxim  Criciúma  \
# IPC_CD
# A01                                      1        0      0         0
# A21                                      0        0      0         1
# A22                                      0        0      0         0
# A23                                      0        0      0         1
# A24                                      0        0      0         1
# ...                                    ...      ...    ...       ...
# H02                                      1        1      0         0
# H03                                      0        0      0         0
# H04                                      1        0      0         0
# H05                                      1        0      0         0
# H99                                      0        0      0         0
#
# RG_IMEDI  Cruz Alta  Cruz das Almas  Cruzeiro  Cruzeiro do Sul  Cuiabá  \
# IPC_CD
# A01               1               0         0                0       1
# A21               0               1         0                0       1
# A22               0               0         0                0       1
# A23               0               1         1                0       0
# A24               0               0         0                0       1
# ...             ...             ...       ...              ...     ...
# H02               0               1         0                0       1
# H03               0               1         0                0       0
# H04               0               1         0                0       0
# H05               0               0         1                0       1
# H99               0               0         0                0       0
#
# RG_IMEDI  Curitiba  Curitibanos  Currais Novos  Curvelo  Cáceres  \
# IPC_CD
# A01              0            1              0        0        0
# A21              1            0              0        0        0
# A22              0            0              0        0        0
# A23              0            0              0        0        1
# A24              0            0              0        0        0
# ...            ...          ...            ...      ...      ...
# H02              1            0              0        0        0
# H03              0            0              0        0        0
# H04              0            0              0        1        0
# H05              1            1              0        0        0
# H99              0            0              0        0        0
#
# RG_IMEDI  Cícero Dantas  Diamantina  Diamantino  Distrito Federal  \
# IPC_CD
# A01                   1           0           0                 0
# A21                   0           0           0                 0
# A22                   0           0           0                 0
# A23                   0           1           0                 0
# A24                   0           0           0                 0
# ...                 ...         ...         ...               ...
# H02                   0           0           0                 1
# H03                   0           0           0                 1
# H04                   0           0           0                 1
# H05                   0           0           0                 0
# H99                   0           0           0                 0
#
# RG_IMEDI  Divinópolis  Dois Vizinhos  Dores do Indaiá  Dourados  Dracena  \
# IPC_CD
# A01                 0              1                1         1        1
# A21                 1              0                0         0        0
# A22                 0              1                0         0        1
# A23                 0              0                1         1        1
# A24                 1              0                0         0        1
# ...               ...            ...              ...       ...      ...
# H02                 0              0                1         0        0
# H03                 1              0                0         0        0
# H04                 1              0                0         0        0
# H05                 1              1                0         0        0
# H99                 0              0                0         0        0
#
# RG_IMEDI  Encantado  Erechim  Escada - Ribeirão  Espinosa  Estância  \
# IPC_CD
# A01               1        1                  1         0         0
# A21               1        1                  0         0         0
# A22               0        1                  0         0         0
# A23               1        1                  0         0         0
# A24               0        0                  0         0         0
# ...             ...      ...                ...       ...       ...
# H02               0        0                  0         0         0
# H03               0        0                  0         0         0
# H04               0        0                  0         0         0
# H05               0        0                  0         0         0
# H99               0        0                  0         0         0
#
# RG_IMEDI  Eunápolis - Porto Seguro  Feira de Santana  Fernandópolis  \
# IPC_CD
# A01                              0                 0              0
# A21                              0                 1              0
# A22                              0                 0              0
# A23                              0                 0              0
# A24                              0                 0              0
# ...                            ...               ...            ...
# H02                              1                 0              0
# H03                              0                 0              0
# H04                              1                 0              0
# H05                              0                 0              0
# H99                              0                 0              0
#
# RG_IMEDI  Flores de Goiás  Florianópolis  Formiga  Fortaleza  Foz do Iguaçu  \
# IPC_CD
# A01                     0              0        1          0              1
# A21                     0              0        1          1              0
# A22                     0              1        1          0              1
# A23                     0              0        0          1              1
# A24                     0              1        1          0              1
# ...                   ...            ...      ...        ...            ...
# H02                     1              1        1          1              1
# H03                     0              0        0          0              0
# H04                     0              1        0          0              0
# H05                     0              0        0          0              0
# H99                     0              0        0          0              0
#
# RG_IMEDI  Franca  Francisco Beltrão  Frederico Westphalen  Frutal  Garanhuns  \
# IPC_CD
# A01            1                  1                     1       1          1
# A21            0                  0                     0       0          0
# A22            0                  1                     0       0          0
# A23            0                  0                     1       0          0
# A24            0                  0                     0       0          0
# ...          ...                ...                   ...     ...        ...
# H02            0                  0                     0       0          0
# H03            0                  0                     0       0          0
# H04            0                  0                     0       0          0
# H05            0                  0                     0       0          0
# H99            0                  0                     0       0          0
#
# RG_IMEDI  Goiana ¿ Timbaúba  Goiás - Itapuranga  Goiânia  \
# IPC_CD
# A01                       1                   0        0
# A21                       1                   0        1
# A22                       0                   0        0
# A23                       0                   1        1
# A24                       0                   0        1
# ...                     ...                 ...      ...
# H02                       0                   1        0
# H03                       0                   0        0
# H04                       0                   0        0
# H05                       0                   1        0
# H99                       0                   0        0
#
# RG_IMEDI  Governador Nunes Freire  Governador Valadares  Guanambi  Guanhães  \
# IPC_CD
# A01                             0                     0         1         1
# A21                             0                     0         0         0
# A22                             0                     0         0         0
# A23                             0                     0         0         0
# A24                             0                     0         0         0
# ...                           ...                   ...       ...       ...
# H02                             0                     0         0         1
# H03                             0                     0         0         0
# H04                             0                     0         0         0
# H05                             0                     0         0         1
# H99                             0                     0         0         0
#
# RG_IMEDI  Guarabira  Guarapuava  Guaratinguetá  Guaxupé  Gurupi  Ibaiti  \
# IPC_CD
# A01               1           1              0        1       0       0
# A21               0           0              0        0       0       0
# A22               0           0              0        0       0       0
# A23               0           1              1        1       0       0
# A24               0           0              0        0       0       0
# ...             ...         ...            ...      ...     ...     ...
# H02               0           0              0        1       0       0
# H03               0           0              0        0       0       0
# H04               0           0              0        0       0       0
# H05               0           0              1        0       0       0
# H99               0           0              0        0       0       0
#
# RG_IMEDI  Ibirama - Presidente Getúlio  Ijuí  Ilhéus ¿ Itabuna  Imperatriz  \
# IPC_CD
# A01                                  1     1                 1           0
# A21                                  0     0                 0           0
# A22                                  0     0                 0           0
# A23                                  0     0                 1           0
# A24                                  0     0                 0           0
# ...                                ...   ...               ...         ...
# H02                                  0     0                 0           1
# H03                                  0     0                 0           1
# H04                                  0     0                 1           0
# H05                                  0     0                 1           0
# H99                                  0     0                 0           0
#
# RG_IMEDI  Inhumas - Itaberaí - Anicuns  Ipatinga  Ipiaú  Iporá  Irati  Irecê  \
# IPC_CD
# A01                                  1         0      0      0      1      1
# A21                                  0         0      0      0      0      0
# A22                                  0         0      0      0      0      0
# A23                                  1         0      0      0      0      1
# A24                                  0         0      0      0      0      0
# ...                                ...       ...    ...    ...    ...    ...
# H02                                  1         1      0      0      0      0
# H03                                  0         0      0      0      0      0
# H04                                  0         0      0      0      0      0
# H05                                  0         1      0      0      0      0
# H99                                  0         0      0      0      0      0
#
# RG_IMEDI  Itabaiana  Itabira  Itacoatiara  Itaituba  Itajaí  Itajubá  \
# IPC_CD
# A01               0        0            0         0       0        0
# A21               0        0            0         0       0        0
# A22               0        0            0         0       1        0
# A23               0        0            0         1       1        0
# A24               0        0            0         0       0        0
# ...             ...      ...          ...       ...     ...      ...
# H02               1        0            0         1       0        0
# H03               0        0            0         0       0        1
# H04               0        1            0         0       0        0
# H05               0        0            0         0       0        0
# H99               0        0            0         0       0        0
#
# RG_IMEDI  Itapecuru Mirim  Itaperuna  Itapetinga  Itapetininga  Itapeva  \
# IPC_CD
# A01                     0          0           0             1        1
# A21                     0          1           0             1        0
# A22                     0          0           0             0        0
# A23                     0          0           0             1        1
# A24                     0          0           0             0        0
# ...                   ...        ...         ...           ...      ...
# H02                     0          1           0             0        1
# H03                     0          0           0             0        0
# H04                     0          0           0             0        0
# H05                     0          0           0             0        0
# H99                     0          0           0             0        0
#
# RG_IMEDI  Itapipoca  Ituiutaba  Itumbiara  Ituporanga  Iturama  Ituverava  \
# IPC_CD
# A01               0          1          1           1        1          1
# A21               0          0          0           0        0          0
# A22               0          0          0           0        0          1
# A23               1          1          1           1        0          1
# A24               0          0          0           0        0          0
# ...             ...        ...        ...         ...      ...        ...
# H02               0          1          1           0        0          0
# H03               0          0          0           0        0          0
# H04               0          1          0           0        0          0
# H05               0          0          0           0        0          0
# H99               0          0          0           0        0          0
#
# RG_IMEDI  Ivaiporã  Jaciara  Jacobina  Jales  Janaúba  Januária  Jardim  Jaru  \
# IPC_CD
# A01              1        0         0      1        0         0       0     0
# A21              0        0         0      0        0         0       0     0
# A22              0        0         0      0        0         0       0     0
# A23              0        0         0      1        1         1       1     0
# A24              0        0         0      0        0         0       0     0
# ...            ...      ...       ...    ...      ...       ...     ...   ...
# H02              0        0         0      0        0         0       1     0
# H03              0        0         0      0        0         0       0     0
# H04              0        1         0      1        0         0       0     0
# H05              1        0         0      0        0         0       0     0
# H99              0        0         0      0        0         0       0     0
#
# RG_IMEDI  Jataí-Mineiros  Jaú  Jequié  Ji-Paraná  Joaçaba - Herval d'Oeste  \
# IPC_CD
# A01                    1    1       0          1                         1
# A21                    0    0       0          0                         1
# A22                    1    0       0          0                         1
# A23                    0    0       1          1                         0
# A24                    0    0       1          0                         0
# ...                  ...  ...     ...        ...                       ...
# H02                    0    0       1          0                         0
# H03                    0    0       0          0                         0
# H04                    1    0       0          0                         0
# H05                    0    1       0          0                         0
# H99                    0    0       0          0                         0
#
# RG_IMEDI  Joinville  João Câmara  João Monlevade  João Pessoa  Juara  \
# IPC_CD
# A01               0            0               1            0      0
# A21               0            0               0            1      0
# A22               1            0               0            1      0
# A23               0            0               0            1      0
# A24               1            0               0            0      0
# ...             ...          ...             ...          ...    ...
# H02               1            0               0            0      1
# H03               0            0               0            1      0
# H04               0            0               0            1      0
# H05               1            0               0            0      0
# H99               0            0               0            0      0
#
# RG_IMEDI  Juazeiro  Juazeiro do Norte  Juiz de Fora  Jundiaí  Juína  Lagarto  \
# IPC_CD
# A01              1                  0             0        0      1        1
# A21              0                  0             0        0      0        0
# A22              0                  0             0        1      0        0
# A23              0                  1             0        0      0        1
# A24              0                  0             0        0      0        0
# ...            ...                ...           ...      ...    ...      ...
# H02              0                  0             1        0      0        1
# H03              0                  0             1        0      0        0
# H04              1                  1             1        0      0        0
# H05              0                  0             1        0      0        0
# H99              0                  0             0        0      0        0
#
# RG_IMEDI  Lages  Lagoa Vermelha  Lajeado  \
# IPC_CD
# A01           1               1        1
# A21           1               0        1
# A22           1               0        1
# A23           1               1        1
# A24           1               0        1
# ...         ...             ...      ...
# H02           0               0        0
# H03           1               0        0
# H04           1               0        1
# H05           0               0        0
# H99           0               0        0
#
# RG_IMEDI  Laranjeiras do Sul - Quedas do Iguaçu  Lavras  Limeira  Limoeiro  \
# IPC_CD
# A01                                           1       1        1         0
# A21                                           0       0        1         0
# A22                                           0       0        1         0
# A23                                           0       1        1         0
# A24                                           0       1        0         0
# ...                                         ...     ...      ...       ...
# H02                                           0       0        0         0
# H03                                           0       0        0         0
# H04                                           0       0        0         0
# H05                                           0       0        0         0
# H99                                           0       0        0         0
#
# RG_IMEDI  Linhares  Lins  Loanda  Londrina  Luziânia  Macapá  \
# IPC_CD
# A01              1     0       1         0         1       1
# A21              1     0       0         0         0       0
# A22              0     0       0         0         0       0
# A23              1     0       1         1         0       1
# A24              0     0       0         1         0       0
# ...            ...   ...     ...       ...       ...     ...
# H02              1     0       0         0         1       0
# H03              0     0       0         0         0       0
# H04              0     1       0         1         1       1
# H05              0     1       0         0         0       0
# H99              0     0       0         0         0       0
#
# RG_IMEDI  Macaé - Rio das Ostras  Maceió  Mafra  Manaus  Manhuaçu  Manicoré  \
# IPC_CD
# A01                            0       1      1       0         1         1
# A21                            1       0      0       1         1         0
# A22                            0       0      0       0         0         0
# A23                            0       1      0       1         1         0
# A24                            0       0      1       0         0         0
# ...                          ...     ...    ...     ...       ...       ...
# H02                            0       0      0       0         0         0
# H03                            0       1      0       1         0         0
# H04                            0       0      0       1         1         0
# H05                            0       0      1       1         0         0
# H99                            0       0      0       0         0         0
#
# RG_IMEDI  Mantena  Marabá  Marau  Maravilha  Marechal Cândido Rondon  Maringá  \
# IPC_CD
# A01             1       1      1          1                        1        0
# A21             0       0      1          0                        0        1
# A22             0       0      1          0                        0        0
# A23             0       0      1          0                        1        1
# A24             0       0      0          0                        0        1
# ...           ...     ...    ...        ...                      ...      ...
# H02             0       0      0          1                        0        0
# H03             0       0      0          0                        0        1
# H04             0       0      0          1                        0        0
# H05             0       0      0          1                        0        0
# H99             0       0      0          0                        0        0
#
# RG_IMEDI  Marília  Miracema do Tocantins  Mirassol D'oeste  Mogi Guaçu  \
# IPC_CD
# A01             1                      0                 1           1
# A21             1                      0                 0           0
# A22             1                      0                 0           0
# A23             1                      0                 0           1
# A24             0                      0                 0           0
# ...           ...                    ...               ...         ...
# H02             1                      0                 0           0
# ...
# H05                           0                 1                   0
# H99                           0                 0                   0
#
# RG_IMEDI  São Lourenço  São Lourenço do Oeste  São Luiz Gonzaga  São Luís  \
# IPC_CD
# A01                  0                      1                 1         0
# A21                  0                      1                 0         1
# A22                  0                      0                 0         0
# A23                  1                      1                 0         1
# A24                  0                      0                 0         0
# ...                ...                    ...               ...       ...
# H02                  0                      0                 0         0
# H03                  0                      0                 0         1
# H04                  1                      0                 0         0
# H05                  0                      0                 0         0
# H99                  0                      0                 0         0
#
# RG_IMEDI  São Luís de Montes Belos  São Mateus  São Miguel do Oeste  \
# IPC_CD
# A01                              1           1                    1
# A21                              0           0                    1
# A22                              1           0                    0
# A23                              0           1                    1
# A24                              0           0                    0
# ...                            ...         ...                  ...
# H02                              0           1                    0
# H03                              0           0                    0
# H04                              0           0                    0
# H05                              0           0                    0
# H99                              0           0                    0
#
# RG_IMEDI  São Miguel dos Campos  São Paulo  São Paulo do Potengi  \
# IPC_CD
# A01                           0          0                     0
# A21                           0          0                     0
# A22                           0          0                     0
# A23                           0          0                     0
# A24                           0          0                     0
# ...                         ...        ...                   ...
# H02                           0          0                     0
# H03                           0          0                     0
# H04                           0          1                     0
# H05                           0          1                     0
# H99                           0          0                     0
#
# RG_IMEDI  São Raimundo Nonato  São Sebastião do Paraíso  Tangará da Serra  \
# IPC_CD
# A01                         1                         1                 1
# A21                         0                         0                 1
# A22                         0                         0                 0
# A23                         0                         1                 0
# A24                         0                         0                 0
# ...                       ...                       ...               ...
# H02                         0                         0                 0
# H03                         0                         0                 0
# H04                         0                         0                 0
# H05                         0                         0                 0
# H99                         0                         0                 0
#
# RG_IMEDI  Tapejara - Sananduva  Taquara - Parobé - Igrejinha  Tarauacá  Tatuí  \
# IPC_CD
# A01                          1                             0         0      0
# A21                          0                             0         0      0
# A22                          0                             0         0      0
# A23                          0                             0         0      0
# A24                          0                             0         0      0
# ...                        ...                           ...       ...    ...
# H02                          0                             0         0      1
# H03                          0                             0         0      0
# H04                          0                             0         0      0
# H05                          0                             0         0      0
# H99                          0                             0         0      0
#
# RG_IMEDI  Taubaté - Pindamonhangaba  Tefé  Teixeira de Freitas  \
# IPC_CD
# A01                               0     0                    0
# A21                               0     0                    0
# A22                               0     0                    0
# A23                               0     1                    1
# A24                               0     0                    0
# ...                             ...   ...                  ...
# H02                               1     0                    0
# H03                               0     0                    0
# H04                               1     0                    1
# H05                               0     0                    0
# H99                               0     0                    0
#
# RG_IMEDI  Telêmaco Borba  Teresina  Teófilo Otoni  Timon  Tocantinópolis  \
# IPC_CD
# A01                    1         0              1      0               0
# A21                    0         1              0      0               0
# A22                    0         1              0      0               0
# A23                    0         1              1      0               1
# A24                    0         0              0      0               0
# ...                  ...       ...            ...    ...             ...
# H02                    0         0              0      0               0
# H03                    0         1              0      0               0
# H04                    0         0              0      0               0
# H05                    0         0              0      0               0
# H99                    0         0              0      0               0
#
# RG_IMEDI  Toledo  Torres  Tramandaí - Osório  Três Corações  Três Lagoas  \
# IPC_CD
# A01            1       1                   0              1            1
# A21            0       0                   1              0            0
# A22            1       0                   0              0            0
# A23            0       0                   0              1            0
# A24            1       0                   1              0            0
# ...          ...     ...                 ...            ...          ...
# H02            0       0                   0              1            0
# H03            0       1                   0              0            0
# H04            0       0                   1              0            0
# H05            0       0                   1              0            0
# H99            0       0                   0              0            0
#
# RG_IMEDI  Três Passos  Três Pontas - Boa Esperança  \
# IPC_CD
# A01                 1                            1
# A21                 1                            0
# A22                 0                            0
# A23                 0                            1
# A24                 0                            0
# ...               ...                          ...
# H02                 0                            0
# H03                 0                            0
# H04                 0                            0
# H05                 0                            0
# H99                 0                            0
#
# RG_IMEDI  Três Rios - Paraíba do Sul  Três de Maio  Tubarão  \
# IPC_CD
# A01                                0             1        0
# A21                                0             0        0
# A22                                0             0        1
# A23                                0             0        0
# A24                                0             0        1
# ...                              ...           ...      ...
# H02                                0             0        0
# H03                                0             0        1
# H04                                0             0        1
# H05                                0             0        0
# H99                                0             0        0
#
# RG_IMEDI  Tucumã - São Félix do Xingu  Tucuruí  Tupã  Tutóia - Araioses  \
# IPC_CD
# A01                                 0        1     1                  0
# A21                                 0        0     0                  0
# A22                                 0        0     1                  0
# A23                                 0        0     1                  1
# A24                                 0        0     0                  0
# ...                               ...      ...   ...                ...
# H02                                 0        0     0                  0
# H03                                 0        0     0                  0
# H04                                 0        0     0                  0
# H05                                 0        0     0                  0
# H99                                 0        0     0                  0
#
# RG_IMEDI  Uberaba  Uberlândia  Ubá  Umuarama  Unaí  União da Vitória  \
# IPC_CD
# A01             1           1    0         1     1                 1
# A21             1           0    0         0     0                 0
# A22             0           0    0         0     0                 0
# A23             0           0    0         1     1                 0
# A24             0           0    0         0     0                 0
# ...           ...         ...  ...       ...   ...               ...
# H02             1           1    0         1     0                 0
# H03             0           1    0         0     0                 0
# H04             0           0    0         0     0                 1
# H05             1           0    0         0     0                 0
# H99             0           0    0         0     0                 0
#
# RG_IMEDI  União dos Palmares  Uruaçu - Niquelândia  Uruguaiana  Vacaria  \
# IPC_CD
# A01                        0                     0           1        1
# A21                        0                     0           0        1
# A22                        0                     0           0        0
# A23                        0                     0           1        1
# A24                        0                     0           0        1
# ...                      ...                   ...         ...      ...
# H02                        0                     0           1        1
# H03                        0                     0           0        0
# H04                        0                     0           0        0
# H05                        0                     0           0        0
# H99                        0                     0           0        0
#
# RG_IMEDI  Valença  Valença do Piauí  Varginha  Viana  Videira  Vilhena  \
# IPC_CD
# A01             0                 1         1      0        1        0
# A21             0                 0         0      0        0        0
# A22             0                 0         0      0        1        0
# A23             0                 0         1      0        1        0
# A24             0                 0         0      0        1        0
# ...           ...               ...       ...    ...      ...      ...
# H02             1                 0         0      0        0        0
# H03             0                 0         1      0        0        0
# H04             1                 0         0      0        0        0
# H05             0                 0         0      0        0        0
# H99             0                 0         0      0        0        0
#
# RG_IMEDI  Vitória  Vitória da Conquista  Vitória de Santo Antão  Viçosa  \
# IPC_CD
# A01             0                     0                       0       1
# A21             0                     0                       0       1
# A22             0                     0                       0       1
# A23             0                     1                       0       1
# A24             0                     0                       0       0
# ...           ...                   ...                     ...     ...
# H02             0                     0                       0       0
# H03             0                     0                       0       0
# H04             0                     0                       0       0
# H05             0                     0                       0       0
# H99             0                     0                       0       0
#
# RG_IMEDI  Volta Redonda - Barra Mansa  Votuporanga  Xanxerê  Xinguara  \
# IPC_CD
# A01                                 0            0        1         0
# A21                                 0            0        0         0
# A22                                 0            0        1         0
# A23                                 0            0        1         0
# A24                                 0            0        0         0
# ...                               ...          ...      ...       ...
# H02                                 0            0        0         0
# H03                                 1            0        0         0
# H04                                 0            0        0         0
# H05                                 0            0        0         0
# H99                                 0            0        0         0
#
# RG_IMEDI  Água Boa  Águas Formosas  Águas Lindas de Goiás
# IPC_CD
# A01              1               0                      1
# A21              0               0                      0
# A22              0               0                      0
# A23              0               0                      0
# A24              0               0                      0
# ...            ...             ...                    ...
# H02              1               0                      0
# H03              0               0                      0
# H04              0               0                      0
# H05              0               0                      0
# H99              0               0                      0
#
# [127 rows x 441 columns]

# %% [markdown]
# ## Construindo índices

# %%
# obtendo as colunas (subdivisões regionais)
regioes = list(tabela_RTA.columns)

# obtendo as linhas (subdivisões do código IPC)
clas_tec = list(tabela_RTA.index)

# %% [markdown]
# ### Índice de diversidade das cidades

# %%
# gerando indices de diversidade para cada regiao
divers = {}
for regiao in regioes:
    divers.update({regiao: tabela_RTA[regiao].sum()})

# mostrando os dados na tela
for regiao in sorted(divers, key=divers.get, reverse=True):
    print(divers[regiao], regiao)
# Out:
# 56 Rio de Janeiro
# 55 São Paulo
# 52 Salvador
# 51 Blumenau
# 51 Campinas
# 51 São José dos Campos
# 49 Belo Horizonte
# 49 Vitória
# 48 Curitiba
# 47 Jundiaí
# 47 Sorocaba
# 47 São Carlos
# 46 Divinópolis
# 46 Florianópolis
# 46 Porto Alegre
# 45 Cuiabá
# 45 Tubarão
# 44 Maringá
# 44 Poços de Caldas
# 44 Uberlândia
# 43 Brusque
# 43 Rio Claro
# 42 Itajaí
# 42 Novo Hamburgo - São Leopoldo
# 42 Volta Redonda - Barra Mansa
# 41 Belém
# 41 Chapecó
# 41 Joinville
# 41 Juiz de Fora
# 41 Taubaté - Pindamonhangaba
# 40 Apucarana
# 40 Santos
# 39 Campo Grande
# 39 Sete Lagoas
# 38 Limeira
# 38 Piracicaba
# 38 Recife
# 38 Santa Maria
# 37 Caraguatatuba - Ubatuba - São Sebastião
# 37 Foz do Iguaçu
# 37 Lajeado
# 37 Londrina
# 37 Natal
# 37 Santa Bárbara - Ouro Preto
# 36 Bragança Paulista
# 36 Ipatinga
# 36 Ponta Grossa
# 36 Presidente Prudente
# 36 Uberaba
# 35 Concórdia
# 35 Fortaleza
# 35 Goiânia
# 35 Guarapuava
# 35 João Pessoa
# 35 Linhares
# 35 Manaus
# 35 Petrópolis
# 35 São Luís
# 34 Campos dos Goytacazes
# 34 Cascavel
# 34 Criciúma
# 34 Itajubá
# 34 Pouso Alegre
# 34 Ribeirão Preto
# 34 Rio do Sul
# 34 São José do Rio Preto
# 33 Caxias do Sul
# 33 Distrito Federal
# 33 Macaé - Rio das Ostras
# 32 Bauru
# 32 Lages
# 32 Montes Claros
# 32 Nova Friburgo
# 31 Erechim
# 31 Guaratinguetá
# 31 Ilhéus ¿ Itabuna
# 31 Joaçaba - Herval d'Oeste
# 31 Marília
# 30 Feira de Santana
# 30 São Bento do Sul - Rio Negrinho
# 29 Aracaju
# 29 Araranguá
# 29 Araçatuba
# 29 Cabo Frio
# 29 Campina Grande
# 29 Conselheiro Lafaiete
# 29 Francisco Beltrão
# 29 Governador Valadares
# 29 Itapetininga
# 29 Santa Cruz do Sul
# 29 Toledo
# 28 Amparo
# 28 Anápolis
# 28 Birigui - Penápolis
# 28 Botucatu
# 28 Maceió
# 28 Nova Prata - Guaporé
# 28 Palmas
# 28 Pelotas
# 28 Xanxerê
# 27 Paranaguá
# 27 Resende
# 27 Varginha
# 26 Araras
# 26 Barretos
# 26 Cachoeiro de Itapemirim
# 26 Campo Mourão
# 26 Mogi Guaçu
# 26 Ourinhos
# 25 Araraquara
# 25 Caçador
# 25 Colatina
# 25 Jaú
# 25 Mafra
# 25 Mossoró
# 25 Pato Branco
# 25 Umuarama
# 24 Araxá
# 24 Dourados
# 24 Franca
# 24 São João da Boa Vista
# 24 Tramandaí - Osório
# 24 Tupã
# 23 Afonso Cláudio - Venda Nova do Imigrante - Santa Maria de Jetibá
# 23 Alfenas
# 23 Assis
# 23 Bento Gonçalves
# 23 Catanduva
# 23 Itabira
# 23 Lins
# 23 Montenegro
# 23 Paranavaí
# 23 Teresina
# 22 Dracena
# 22 Itapeva
# 22 São João del Rei
# 22 São Miguel do Oeste
# 22 Viçosa
# 21 Cachoeira do Sul
# 21 Cruzeiro
# 21 Lavras
# 20 Cianorte
# 20 Formiga
# 20 Pará de Minas
# 20 Patos de Minas
# 20 São José do Rio Pardo - Mococa
# 20 Taquara - Parobé - Igrejinha
# 20 Valença
# 19 Avaré
# 19 Maravilha
# 19 Rio Verde
# 19 Tatuí
# 19 Três Rios - Paraíba do Sul
# 19 Ubá
# 19 Videira
# 18 Bagé
# 18 Barreiras
# 18 Camaquã
# 18 Caruaru
# 18 Dores do Indaiá
# 18 Fernandópolis
# 18 Goiás - Itapuranga
# 18 João Monlevade
# 18 Marechal Cândido Rondon
# 18 Passos
# 18 Pirapora
# 18 São Joaquim da Barra ¿ Orlândia
# 18 São Mateus
# 18 Vitória da Conquista
# 17 Boa Vista
# 17 Carazinho
# 17 Charqueadas - Triunfo - São Jerônimo
# 17 Cornélio Procópio ¿ Bandeirantes
# 17 Curvelo
# 17 Ijuí
# 17 Jataí-Mineiros
# 17 Ponte Nova
# 17 Santa Rosa
# 17 Sinop
# 17 Tangará da Serra
# 17 União da Vitória
# 17 Vacaria
# 17 Águas Lindas de Goiás
# 16 Andradina
# 16 Barbacena
# 16 Cacoal
# 16 Cataguases
# 16 Luziânia
# 16 Sorriso
# 15 Juazeiro
# 15 Macapá
# 15 Marau
# 15 Muriaé
# 15 Nova Venécia
# 15 Passo Fundo
# 15 Porto Velho
# 15 Rondonópolis
# 14 Arapiraca
# 14 Campo Belo
# 14 Curitibanos
# 14 Diamantina
# 14 Dois Vizinhos
# 14 Guaxupé
# 14 Ibirama - Presidente Getúlio
# 14 Manhuaçu
# 14 Petrolina
# 14 Santo Antônio da Platina
# 14 Soledade
# 14 São Lourenço
# 14 Torres
# 13 Cruz Alta
# 13 Cruz das Almas
# 13 Eunápolis - Porto Seguro
# 13 Irati
# 13 Ituverava
# 13 Jales
# 13 Rio Branco
# 13 Telêmaco Borba
# 13 Três Corações
# 12 Alagoinhas
# 12 Angra dos Reis
# 12 Caldas Novas-Morrinhos
# 12 Imperatriz
# 12 Itaperuna
# 12 Itumbiara
# 12 Ituporanga
# 12 Juazeiro do Norte
# 12 Patrocínio
# 12 Tapejara - Sananduva
# 12 Teixeira de Freitas
# 12 Uruguaiana
# 11 Adamantina - Lucélia
# 11 Ariquemes
# 11 Belo Jardim ¿ Pesqueira
# 11 Catalão
# 11 Frederico Westphalen
# 11 Registro
# 11 Sobral
# 11 Teófilo Otoni
# 11 Três de Maio
# 11 Vilhena
# 10 Açailândia
# 10 Guanhães
# 10 Ituiutaba
# 10 Ivaiporã
# 10 Jequié
# 10 Lagarto
# 10 Lagoa Vermelha
# 10 Oliveira
# 10 Rio Bonito
# 10 Russas - Limoeiro do Norte
# 10 Santarém
# 10 Santo Ângelo
# 10 Três Lagoas
# 10 Votuporanga
# 10 Água Boa
# 9 Alegre
# 9 Araguaína
# 9 Barra do Garças
# 9 Caratinga
# 9 Iturama
# 9 Loanda
# 9 Piraju
# 9 Presidente Epitácio-Presidente Venceslau
# 9 São Gabriel - Caçapava do Sul
# 9 Três Pontas - Boa Esperança
# 8 Capelinha
# 8 Carpina
# 8 Itapipoca
# 8 Ji-Paraná
# 8 Paranaíba - Chapadão do Sul - Cassilândia
# 8 Parnaíba
# 8 Piracanjuba
# 8 São Lourenço do Oeste
# 8 Tucuruí
# 8 Unaí
# 7 Aracati
# 7 Arcoverde
# 7 Ceres - Rialma - Goianésia
# 7 Goiana ¿ Timbaúba
# 7 Inhumas - Itaberaí - Anicuns
# 7 Irecê
# 7 Mantena
# 7 Porangatu
# 7 Primavera do Leste
# 7 Santa Fé do Sul
# 6 Carangola
# 6 Castanhal
# 6 Caxambu - Baependi
# 6 Cáceres
# 6 Cícero Dantas
# 6 Encantado
# 6 Garanhuns
# 6 Janaúba
# 6 Jardim
# 6 Juína
# 6 Laranjeiras do Sul - Quedas do Iguaçu
# 6 Marabá
# 6 Monte Carmelo
# 6 Naviraí - Mundo Novo
# 6 Paragominas
# 6 Pontes e Lacerda - Comodoro
# 6 Santana do Livramento
# 6 Sobradinho
# 6 São Borja
# 6 São Luiz Gonzaga
# 5 Aimorés - Resplendor
# 5 Frutal
# 5 Guanambi
# 5 Ibaiti
# 5 Santo Antônio de Jesus
# 5 Santo Antônio de Pádua
# 5 São Sebastião do Paraíso
# 4 Araripina
# 4 Iporá
# 4 Jaciara
# 4 Jaru
# 4 Palmeiras de Goiás
# 4 Paranacity - Colorado
# 4 Ponta Porã
# 4 Santa Inês
# 4 Seabra
# 4 Senhor do Bonfim
# 4 Serra Talhada
# 4 São Benedito - Ipu - Guaraciaba do Norte - Tianguá
# 4 Tutóia - Araioses
# 3 Abaetetuba
# 3 Além Paraíba
# 3 Açu
# 3 Caicó
# 3 Canguaretama
# 3 Confresa - Vila Rica
# 3 Cruzeiro do Sul
# 3 Diamantino
# 3 Guarabira
# 3 Gurupi
# 3 Mirassol D'oeste
# 3 Nazaré ¿ Maragogipe
# 3 Nonoai
# 3 Parauapebas
# 3 Patos
# 3 Pedreiras
# 3 Picos
# 3 Pinheiro
# 3 Piumhi
# 3 Quirinópolis
# 3 Salinas
# 3 Três Passos
# 3 Uruaçu - Niquelândia
# 2 Abaeté
# 2 Alta Floresta
# 2 Amambai
# 2 Aquidauana - Anastácio
# 2 Bacabal
# 2 Balsas
# 2 Barreiros - Sirinhaém
# 2 Brasiléia
# 2 Brumado
# 2 Corumbá
# 2 Coxim
# 2 Currais Novos
# 2 Espinosa
# 2 Itacoatiara
# 2 Itaituba
# 2 Itapetinga
# 2 Jacobina
# 2 Januária
# 2 Manicoré
# 2 Nova Andradina
# 2 Parintins
# 2 Paulo Afonso
# 2 Penedo
# 2 Pitanga
# 2 Posse-Campos Belos
# 2 Redenção-Acarape
# 2 Salgueiro
# 2 Santana do Ipanema
# 2 Santiago
# 2 Santo Antônio - Passa e Fica - Nova Cruz
# 2 Surubim
# 2 São Francisco
# 2 São João Nepomuceno - Bicas
# 2 São Luís de Montes Belos
# 2 Timon
# 2 Tucumã - São Félix do Xingu
# 2 Viana
# 2 Vitória de Santo Antão
# 1 Almenara
# 1 Araçuaí
# 1 Barra do Corda
# 1 Bom Jesus da Lapa
# 1 Breves
# 1 Cajazeiras
# 1 Camacan
# 1 Campo Maior
# 1 Canindé
# 1 Caracaraí
# 1 Cerro Largo
# 1 Chapadinha
# 1 Colinas do Tocantins
# 1 Conceição do Coité
# 1 Escada - Ribeirão
# 1 Estância
# 1 Flores de Goiás
# 1 Governador Nunes Freire
# 1 Ipiaú
# 1 Itabaiana
# 1 Itapecuru Mirim
# 1 João Câmara
# 1 Juara
# 1 Limoeiro
# 1 Miracema do Tocantins
# 1 Monteiro
# 1 Oriximiná
# 1 Palmares
# 1 Palmeira das Missões
# 1 Palmeira dos Índios
# 1 Pedra Azul
# 1 Peixoto de Azevedo - Guarantã do Norte
# 1 Pires do Rio
# 1 Piripiri
# 1 Pombal
# 1 Porto Nacional
# 1 Propriá
# 1 Redenção
# 1 Rorainópolis
# 1 Santa Cruz
# 1 Sena Madureira
# 1 Serrinha
# 1 São Gabriel da Cachoeira
# 1 São João dos Patos
# 1 São Miguel dos Campos
# 1 São Paulo do Potengi
# 1 São Raimundo Nonato
# 1 Tarauacá
# 1 Tefé
# 1 Tocantinópolis
# 1 União dos Palmares
# 1 Valença do Piauí
# 1 Xinguara
# 1 Águas Formosas

# %% [markdown]
# ### Índice de ubiquidade de classes tecnológicas

# %%
# gerando indices de ubiquidade para cada classe tecnologica
ubiq = {}
for ipc in clas_tec:
    ubiq.update({ipc: int(tabela_RTA.loc[[ipc], :].sum(axis=1))})

# mostrando os dados na tela
for ipc in sorted(ubiq, key=ubiq.get, reverse=True):
    print(ubiq[ipc], ' ', ipc)
# Out:
# 215   A01
# 162   A23
# 136   E04
# 131   B62
# 123   B60
# 121   A47
# 120   A61
# 106   F03
# 102   B01
# 101   A63
# 99   B65
# 99   E03
# 98   B29
# 98   F16
# 94   B27
# 94   B66
# 94   F24
# 94   G09
# 94   H02
# 90   G01
# 87   C02
# 85   C04
# 82   B28
# 80   B05
# 80   B26
# 77   A21
# 75   G06
# 74   A41
# 73   A45
# 73   G08
# 73   H01
# 72   E06
# 71   C08
# 70   B02
# 70   C05
# 70   C10
# 70   E02
# 68   B67
# 68   H04
# 66   F04
# 65   C12
# 65   F02
# 64   B25
# 63   B24
# 62   B23
# 62   E01
# 62   F23
# 62   G05
# 61   G07
# 60   B63
# 60   C09
# 60   H05
# 59   B07
# 59   F26
# 58   D06
# 57   A46
# 57   C11
# 56   E05
# 55   A22
# 55   A62
# 54   A42
# 54   F01
# 53   C01
# 53   F21
# 51   B21
# 51   B30
# 49   B08
# 49   B44
# 47   B42
# 47   F28
# 47   G10
# 46   A24
# 46   B43
# 46   F27
# 45   B09
# 44   B41
# 44   B64
# 43   A44
# 42   C07
# 42   C22
# 42   G02
# 41   C25
# 41   G03
# 40   F41
# 39   B22
# 39   B32
# 39   F17
# 39   H03
# 38   A43
# 38   D21
# 37   E21
# 37   F25
# 34   B03
# 34   G11
# 33   D05
# 30   D04
# 28   B61
# 27   C03
# 27   C23
# 27   F15
# 27   F42
# 26   D01
# 26   D03
# 26   F22
# 24   B04
# 23   C21
# 23   G04
# 22   B31
# 21   C14
# 20   B68
# 20   C13
# 16   B82
# 16   G16
# 15   C06
# 14   G21
# 13   D07
# 12   G12
# 11   D02
# 8   C30
# 6   B33
# 5   B06
# 2   A99
# 2   B81
# 2   C40
# 2   G99
# 1   B99
# 1   H99

# %% [markdown]
# ## Segundo iteração

# %% [markdown]
# ### Ubiquidade média das tecnologias de determinada região

# %%
# 
divers2 = {}
for regiao in regioes:
    indice2 = 0
    for ipc in clas_tec:
        indice2 += ubiq[ipc] * int(tabela_RTA.loc[[ipc], regiao])
    divers2.update({regiao: indice2/divers[regiao]})
    
# 
for regiao in sorted(divers2, key=divers2.get, reverse=False):
    print(regiao, divers2[regiao])
# Out:
# São Paulo do Potengi 13.0
# Conceição do Coité 26.0
# Piripiri 27.0
# São João dos Patos 37.0
# Monteiro 38.0
# Campo Maior 39.0
# Governador Nunes Freire 41.0
# Rorainópolis 42.0
# São Miguel dos Campos 42.0
# Campinas 46.68627450980392
# Cajazeiras 47.0
# Rio de Janeiro 49.732142857142854
# Novo Hamburgo - São Leopoldo 54.095238095238095
# Divinópolis 55.06521739130435
# São Paulo 55.90909090909091
# Juiz de Fora 56.36585365853659
# Chapadinha 57.0
# Palmeira dos Índios 57.0
# Piracicaba 57.05263157894737
# Sorocaba 57.319148936170215
# Manaus 57.57142857142857
# Santa Bárbara - Ouro Preto 57.67567567567568
# São Carlos 57.787234042553195
# Natal 58.32432432432432
# Florianópolis 58.97826086956522
# Distrito Federal 59.15151515151515
# Recife 59.526315789473685
# Joinville 59.853658536585364
# Caxias do Sul 60.06060606060606
# Jundiaí 60.12765957446808
# São José dos Campos 60.19607843137255
# Belo Horizonte 60.326530612244895
# Campina Grande 60.58620689655172
# Ribeirão Preto 60.588235294117645
# Bragança Paulista 60.611111111111114
# Itajubá 60.61764705882353
# São Luís 60.714285714285715
# Porto Alegre 60.71739130434783
# Salvador 60.92307692307692
# Volta Redonda - Barra Mansa 61.166666666666664
# Vitória 61.204081632653065
# Conselheiro Lafaiete 61.241379310344826
# Birigui - Penápolis 61.285714285714285
# Franca 61.666666666666664
# Criciúma 61.705882352941174
# Curitiba 61.729166666666664
# Estância 62.0
# Bento Gonçalves 62.130434782608695
# Chapecó 62.36585365853659
# Ponta Grossa 62.69444444444444
# Ceres - Rialma - Goianésia 62.857142857142854
# Blumenau 62.86274509803921
# Bauru 63.0625
# Petrópolis 63.34285714285714
# Pouso Alegre 63.411764705882355
# Fortaleza 63.42857142857143
# Brusque 63.51162790697674
# Amambai 64.5
# Almenara 65.0
# Tarauacá 65.0
# Macaé - Rio das Ostras 65.06060606060606
# Viana 65.5
# João Pessoa 65.57142857142857
# Rio Claro 65.74418604651163
# Presidente Prudente 65.86111111111111
# Poços de Caldas 65.86363636363636
# Curvelo 65.94117647058823
# Joaçaba - Herval d'Oeste 66.25806451612904
# Tubarão 66.4
# Santana do Ipanema 66.5
# São Bento do Sul - Rio Negrinho 66.66666666666667
# Santos 66.9
# Toledo 66.96551724137932
# Cuiabá 67.26666666666667
# Londrina 67.27027027027027
# Sobral 67.36363636363636
# Maringá 67.47727272727273
# Sete Lagoas 67.92307692307692
# Belém 67.97560975609755
# Pontes e Lacerda - Comodoro 68.0
# Uberlândia 68.04545454545455
# Guarapuava 68.25714285714285
# Taquara - Parobé - Igrejinha 68.65
# Resende 68.74074074074075
# Apucarana 68.95
# Taubaté - Pindamonhangaba 68.95121951219512
# Jaú 69.2
# Santa Maria 69.34210526315789
# Nova Friburgo 69.4375
# Ipatinga 69.77777777777777
# Maceió 70.35714285714286
# São José do Rio Preto 70.44117647058823
# São João Nepomuceno - Bicas 70.5
# Guaratinguetá 70.61290322580645
# Montes Claros 70.625
# Lages 70.6875
# Goiânia 70.85714285714286
# Governador Valadares 70.96551724137932
# Marília 70.96774193548387
# Limeira 71.07894736842105
# Lins 71.17391304347827
# Itajaí 71.26190476190476
# Aracaju 71.27586206896552
# João Monlevade 71.44444444444444
# Valença 71.45
# Cruzeiro do Sul 71.66666666666667
# Campos dos Goytacazes 71.73529411764706
# Dois Vizinhos 71.85714285714286
# Araraquara 72.08
# São João del Rei 72.0909090909091
# Charqueadas - Triunfo - São Jerônimo 72.17647058823529
# Varginha 72.33333333333333
# Uberaba 72.52777777777777
# Araçatuba 72.55172413793103
# Caraguatatuba - Ubatuba - São Sebastião 72.67567567567568
# Angra dos Reis 72.75
# Ubá 72.78947368421052
# Pelotas 72.82142857142857
# Campo Grande 72.94871794871794
# Teresina 72.95652173913044
# Anápolis 73.0
# Fernandópolis 73.22222222222223
# Santa Cruz do Sul 73.37931034482759
# Passo Fundo 73.4
# Imperatriz 73.41666666666667
# Itapetinga 73.5
# Jacobina 73.5
# União da Vitória 73.6470588235294
# Vitória de Santo Antão 74.0
# Cruz Alta 74.23076923076923
# Rio do Sul 74.32352941176471
# Foz do Iguaçu 74.56756756756756
# Concórdia 74.6
# Carpina 74.75
# Catanduva 74.82608695652173
# Cascavel 74.91176470588235
# Cruzeiro 75.0
# Belo Jardim ¿ Pesqueira 75.0909090909091
# Pará de Minas 75.3
# Formiga 75.4
# Amparo 75.71428571428571
# Jaciara 75.75
# Tatuí 75.78947368421052
# Ibaiti 75.8
# Tramandaí - Osório 76.04166666666667
# Viçosa 76.0909090909091
# Lajeado 76.1891891891892
# Paranaguá 76.33333333333333
# São João da Boa Vista 76.45833333333333
# Colatina 76.52
# Araras 76.6923076923077
# Nova Prata - Guaporé 76.89285714285714
# Tangará da Serra 76.94117647058823
# Corumbá 77.0
# Santa Cruz 77.0
# Tucumã - São Félix do Xingu 77.0
# Caruaru 77.05555555555556
# Araranguá 77.10344827586206
# Francisco Beltrão 77.24137931034483
# Xanxerê 77.35714285714286
# Campo Mourão 77.38461538461539
# Cachoeira do Sul 77.71428571428571
# Erechim 77.96774193548387
# Cruz das Almas 78.07692307692308
# Feira de Santana 78.13333333333334
# Muriaé 78.6
# Cachoeiro de Itapemirim 78.96153846153847
# Passos 79.11111111111111
# Botucatu 79.5
# Cabo Frio 79.6896551724138
# Barretos 79.6923076923077
# Lavras 79.71428571428571
# Senhor do Bonfim 79.75
# Ijuí 79.76470588235294
# Arapiraca 80.07142857142857
# Três Rios - Paraíba do Sul 80.10526315789474
# Linhares 80.11428571428571
# Mossoró 80.16
# Mogi Guaçu 80.1923076923077
# Tupã 80.29166666666667
# Porto Velho 80.33333333333333
# Soledade 80.35714285714286
# Bagé 80.38888888888889
# Jataí-Mineiros 80.52941176470588
# Ilhéus ¿ Itabuna 80.74193548387096
# Teixeira de Freitas 80.91666666666667
# Patos de Minas 81.65
# Itabira 81.69565217391305
# Montenegro 81.69565217391305
# Assis 82.0
# Palmas 82.07142857142857
# Alfenas 82.08695652173913
# Vacaria 82.29411764705883
# Araxá 82.33333333333333
# Boa Vista 82.41176470588235
# Ourinhos 82.61538461538461
# Umuarama 82.64
# Mafra 82.8
# Dourados 82.95833333333333
# Carazinho 83.41176470588235
# Rio Verde 83.42105263157895
# Paranavaí 83.56521739130434
# Jequié 84.7
# Santa Rosa 84.70588235294117
# Caçador 84.8
# Cianorte 84.8
# Pato Branco 84.84
# Afonso Cláudio - Venda Nova do Imigrante - Santa Maria de Jetibá 84.8695652173913
# Oliveira 85.1
# Parnaíba 85.125
# Itapetininga 85.20689655172414
# Ivaiporã 85.3
# Caldas Novas-Morrinhos 85.5
# Diamantino 85.66666666666667
# Santo Antônio da Platina 85.78571428571429
# São José do Rio Pardo - Mococa 86.15
# Nazaré ¿ Maragogipe 86.33333333333333
# Marechal Cândido Rondon 86.44444444444444
# Barreiras 86.94444444444444
# Itapeva 87.0
# Oriximiná 87.0
# Cornélio Procópio ¿ Bandeirantes 87.05882352941177
# Cataguases 87.25
# Canguaretama 87.33333333333333
# Pirapora 87.38888888888889
# Águas Lindas de Goiás 87.47058823529412
# Camaquã 87.5
# Aimorés - Resplendor 88.0
# Nonoai 88.0
# Eunápolis - Porto Seguro 88.07692307692308
# Dracena 88.5
# Sinop 88.52941176470588
# Além Paraíba 88.66666666666667
# Rondonópolis 89.06666666666666
# Diamantina 89.07142857142857
# Videira 89.3157894736842
# Confresa - Vila Rica 89.33333333333333
# Votuporanga 89.4
# Marau 89.73333333333333
# Itapecuru Mirim 90.0
# Patos 90.0
# Sorriso 90.0
# Itaperuna 90.16666666666667
# Goiás - Itapuranga 90.27777777777777
# Juazeiro do Norte 90.33333333333333
# São Mateus 90.44444444444444
# São Miguel do Oeste 90.45454545454545
# Avaré 90.47368421052632
# Aquidauana - Anastácio 90.5
# Araripina 90.5
# Vilhena 90.81818181818181
# Janaúba 90.83333333333333
# São Joaquim da Barra ¿ Orlândia 90.83333333333333
# Macapá 91.0
# Cacoal 91.125
# Três Corações 91.15384615384616
# Maravilha 91.21052631578948
# Quirinópolis 91.33333333333333
# Coxim 91.5
# São Lourenço 91.57142857142857
# Luziânia 91.75
# Alagoinhas 91.91666666666667
# Cáceres 92.0
# Vitória da Conquista 92.0
# Curitibanos 92.14285714285714
# Itapipoca 92.375
# Uruguaiana 92.75
# Santiago 93.0
# Barra do Garças 93.22222222222223
# Andradina 93.3125
# Campo Belo 93.57142857142857
# Capelinha 93.875
# Breves 94.0
# Flores de Goiás 94.0
# Itabaiana 94.0
# Juara 94.0
# Limoeiro 94.0
# Palmares 94.0
# Peixoto de Azevedo - Guarantã do Norte 94.0
# Salinas 94.0
# Serrinha 94.0
# Santo Antônio de Jesus 94.4
# Ibirama - Presidente Getúlio 94.42857142857143
# Ponte Nova 94.58823529411765
# Irati 94.92307692307692
# Nova Venécia 95.4
# Dores do Indaiá 95.5
# Uruaçu - Niquelândia 95.66666666666667
# Brumado 96.0
# Torres 96.28571428571429
# Três de Maio 96.45454545454545
# Barbacena 96.6875
# Naviraí - Mundo Novo 96.83333333333333
# Manhuaçu 96.85714285714286
# Brasiléia 97.0
# Currais Novos 97.0
# Parintins 97.0
# Russas - Limoeiro do Norte 97.1
# Petrolina 97.35714285714286
# Telêmaco Borba 97.38461538461539
# Guanambi 97.6
# Juazeiro 97.73333333333333
# Paranacity - Colorado 97.75
# Presidente Epitácio-Presidente Venceslau 97.77777777777777
# Ituiutaba 98.4
# Guaxupé 98.57142857142857
# Santa Inês 99.0
# Tapejara - Sananduva 99.0
# Registro 99.18181818181819
# Jaru 99.5
# Rio Branco 99.84615384615384
# Santo Antônio de Pádua 100.0
# Ariquemes 100.0909090909091
# Garanhuns 100.16666666666667
# Lagarto 100.2
# Ituverava 100.23076923076923
# Caratinga 100.55555555555556
# Ipiaú 101.0
# Pedreiras 101.0
# Primavera do Leste 101.0
# Xinguara 101.0
# Castanhal 101.33333333333333
# Adamantina - Lucélia 101.63636363636364
# Propriá 102.0
# Patrocínio 103.33333333333333
# Iporá 103.75
# Lagoa Vermelha 103.8
# Água Boa 104.1
# Itumbiara 104.33333333333333
# Iturama 104.33333333333333
# Teófilo Otoni 105.0
# Timon 105.0
# Catalão 105.0909090909091
# Guanhães 105.3
# Frederico Westphalen 105.36363636363636
# Jales 105.53846153846153
# Jardim 105.83333333333333
# Araguaína 106.44444444444444
# Loanda 106.55555555555556
# Três Pontas - Boa Esperança 106.77777777777777
# Unaí 106.875
# Caxambu - Baependi 107.0
# Gurupi 107.33333333333333
# Ituporanga 107.33333333333333
# Serra Talhada 107.75
# Paragominas 107.83333333333333
# Três Lagoas 108.2
# Rio Bonito 108.3
# Salgueiro 108.5
# São Gabriel - Caçapava do Sul 108.55555555555556
# Santana do Livramento 108.83333333333333
# Aracati 109.71428571428571
# Porangatu 109.71428571428571
# Santa Fé do Sul 109.71428571428571
# Itacoatiara 110.0
# Santo Antônio - Passa e Fica - Nova Cruz 110.0
# Encantado 110.33333333333333
# Goiana ¿ Timbaúba 110.57142857142857
# Piraju 110.66666666666667
# Alegre 110.88888888888889
# Seabra 111.0
# Santo Ângelo 111.7
# Sobradinho 112.0
# Marabá 113.0
# Posse-Campos Belos 113.0
# Açailândia 113.4
# São Borja 114.83333333333333
# São Lourenço do Oeste 115.0
# Santarém 115.1
# Paranaíba - Chapadão do Sul - Cassilândia 115.25
# Frutal 115.8
# Açu 116.0
# Cícero Dantas 116.66666666666667
# Espinosa 117.0
# Juína 117.0
# Tucuruí 117.125
# Laranjeiras do Sul - Quedas do Iguaçu 119.33333333333333
# Carangola 119.5
# Três Passos 120.0
# Águas Formosas 120.0
# Tutóia - Araioses 120.25
# Balsas 120.5
# Penedo 120.5
# Bom Jesus da Lapa 121.0
# Caracaraí 121.0
# Pombal 121.0
# Sena Madureira 121.0
# São Benedito - Ipu - Guaraciaba do Norte - Tianguá 121.5
# Pinheiro 121.66666666666667
# Palmeiras de Goiás 122.75
# Araçuaí 123.0
# Barra do Corda 123.0
# Colinas do Tocantins 123.0
# João Câmara 123.0
# Pedra Azul 123.0
# Picos 123.66666666666667
# Caicó 124.0
# Mantena 124.28571428571429
# Monte Carmelo 124.83333333333333
# Irecê 125.0
# Guarabira 125.66666666666667
# Ji-Paraná 125.75
# Ponta Porã 126.75
# São Luiz Gonzaga 126.83333333333333
# Bacabal 128.0
# Itaituba 128.0
# Inhumas - Itaberaí - Anicuns 128.57142857142858
# Piracanjuba 129.25
# Surubim 129.5
# Barreiros - Sirinhaém 130.5
# Mirassol D'oeste 130.66666666666666
# Redenção 131.0
# União dos Palmares 131.0
# Parauapebas 132.33333333333334
# Piumhi 132.66666666666666
# São Luís de Montes Belos 135.0
# Arcoverde 135.14285714285714
# Miracema do Tocantins 136.0
# Porto Nacional 136.0
# São Gabriel da Cachoeira 136.0
# Alta Floresta 139.5
# Manicoré 140.0
# Paulo Afonso 141.0
# São Sebastião do Paraíso 141.4
# Abaeté 141.5
# Redenção-Acarape 141.5
# Abaetetuba 145.33333333333334
# Januária 146.5
# Canindé 162.0
# Tefé 162.0
# Tocantinópolis 162.0
# Pitanga 168.0
# São Francisco 168.0
# Nova Andradina 188.5
# Camacan 215.0
# Cerro Largo 215.0
# Escada - Ribeirão 215.0
# Palmeira das Missões 215.0
# Pires do Rio 215.0
# São Raimundo Nonato 215.0
# Valença do Piauí 215.0

# %% [markdown]
# ### Diversidade média das regiões com determinada tecnologia

# %%
#
ubiq2 = {}
ipc = 'A01'

for ipc in clas_tec:
    indice2 = 0
    for regiao in regioes:
        indice2 += divers[regiao] * int(tabela_RTA.loc[[ipc], regiao])
    ubiq2.update({ipc: indice2/ubiq[ipc]})

# mostrando dados
for ipc in sorted(ubiq2, key=ubiq2.get, reverse=True):
    print(ubiq2[ipc], ' ', ipc)
# Out:
# 55.0   B99
# 49.0   H99
# 47.5   G99
# 46.0   B81
# 45.0   B82
# 42.75   C30
# 42.54545454545455   D02
# 42.5   A99
# 42.2   B06
# 41.17391304347826   G04
# 41.0   B33
# 40.166666666666664   G12
# 39.42857142857143   G21
# 37.370370370370374   C23
# 37.27272727272727   B31
# 37.2   D04
# 36.76923076923077   D01
# 36.666666666666664   F42
# 36.666666666666664   G02
# 36.458333333333336   B04
# 36.3   B68
# 36.2   C06
# 36.15384615384615   D03
# 36.15384615384615   D07
# 36.0   C40
# 35.674418604651166   A44
# 35.43589743589744   B22
# 35.38461538461539   F22
# 35.2962962962963   F15
# 35.25   B61
# 35.2   B09
# 35.170212765957444   F28
# 34.888888888888886   C03
# 34.705882352941174   G11
# 34.48780487804878   C25
# 34.10204081632653   B44
# 34.08695652173913   B43
# 33.81818181818182   D05
# 33.8125   G16
# 33.78260869565217   C21
# 33.76470588235294   B03
# 33.421052631578945   D21
# 33.333333333333336   A42
# 33.15384615384615   H03
# 33.0   C14
# 32.680851063829785   G10
# 32.63414634146341   G03
# 32.61538461538461   B32
# 32.56410256410256   F17
# 32.5   F01
# 32.483870967741936   G05
# 32.38095238095238   C22
# 32.2   C13
# 31.85483870967742   B23
# 31.7   C09
# 31.632653061224488   B08
# 31.522727272727273   B41
# 31.418181818181818   A62
# 31.142857142857142   B24
# 31.06451612903226   E01
# 31.019607843137255   B30
# 30.894736842105264   C11
# 30.833333333333332   C07
# 30.82857142857143   B02
# 30.796875   B25
# 30.6   F41
# 30.568627450980394   B21
# 30.228070175438596   A46
# 30.18867924528302   C01
# 30.033898305084747   B07
# 29.77358490566038   F21
# 29.7125   B26
# 29.532258064516128   F23
# 29.37704918032787   G07
# 29.1   H05
# 28.927272727272726   A22
# 28.804347826086957   A24
# 28.75   B67
# 28.67391304347826   F27
# 28.571428571428573   C05
# 28.551724137931036   D06
# 28.48235294117647   C04
# 28.45945945945946   E21
# 28.091836734693878   B29
# 28.09090909090909   B64
# 27.966666666666665   B63
# 27.835616438356166   G08
# 27.341463414634145   B28
# 27.233766233766232   A21
# 27.229885057471265   C02
# 27.205479452054796   H01
# 27.203389830508474   F26
# 27.142857142857142   E02
# 27.127659574468087   B42
# 27.09090909090909   F04
# 26.910714285714285   E05
# 26.542857142857144   C10
# 26.480392156862745   B01
# 26.44   G06
# 26.416666666666668   E06
# 26.4125   B05
# 26.35135135135135   F25
# 26.307692307692307   F02
# 26.225352112676056   C08
# 26.0   A41
# 25.70769230769231   C12
# 25.356164383561644   A45
# 25.19148936170213   F24
# 25.022222222222222   G01
# 24.971698113207548   F03
# 24.970588235294116   H04
# 24.670212765957448   B27
# 24.659574468085108   G09
# 24.404255319148938   B66
# 23.96039603960396   A63
# 23.03191489361702   H02
# 22.525252525252526   E03
# 22.38235294117647   E04
# 22.20408163265306   F16
# 21.564885496183205   B62
# 21.36842105263158   A43
# 21.21212121212121   B65
# 21.05   A61
# 19.438271604938272   A23
# 19.284552845528456   B60
# 17.611570247933884   A47
# 16.75813953488372   A01
